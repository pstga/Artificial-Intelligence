# %%
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.preprocessing import StandardScaler
from sklearn.utils import shuffle
import numpy as np

training_data = np.load("data/training_data.npy")
prices = np.load("data/prices.npy")
training_data, prices = shuffle(training_data, prices, random_state = 0)

training_data = np.array(training_data)
prices = np.array(prices)

def normalizeaza_mi(training_data, test_data):
    scaler = StandardScaler()
    scaler.fit(training_data)
    normalized_trainingdata = scaler.transform(training_data)
    normalized_test_data = scaler.transform(test_data)

    return normalized_trainingdata, normalized_test_data


linear_reg_model = LinearRegression()
ridge_reg_model = Ridge(alpha = 1)
lasso_reg_model = Lasso(alpha = 1)

# mse_val = mean_squared_error(y_true, y_pred)
# mae_value = mean_absolute_error(y_true, y_pred)
